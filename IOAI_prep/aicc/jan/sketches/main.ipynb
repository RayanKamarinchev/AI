# %%
import kagglehub

# Download latest version
path = kagglehub.competition_download('drawn-apart-aicc-round-3')

print("Path to competition files:", path)
# Out:
# ...
# 100%|██████████| 1.52G/1.52G [02:38<00:00, 10.3MB/s]
# Extracting files...
# Path to competition files: C:\Users\raian\.cache\kagglehub\competitions\drawn-apart-aicc-round-3
